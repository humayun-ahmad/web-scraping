# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
driver = webdriver.PhantomJS(executable_path=r'F:\Softwares\phantomJS\phantomjs-2.1.1-windows\phantomjs-2.1.1-windows\bin\phantomjs.exe')
# Out:
# C:\Users\Humayun Ahmad Rajib\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
# def get_amazomoton_product(keyword):
keyword = "phone"
amazon = "https://www.amazon.com/"
# url = amazon+"/s?k="+keyword+"&rh=p_72:2661618011,p_n_condition-type:6461716011&s=relevanceblender&page=1&currency=USD&ref=sr_st_review-rank,sr_pg_1" 
url = amazon+"s?k="+keyword+"&ref=nb_sb_noss_2"
driver.get(url)
# print(driver.status_code)
html_data = BeautifulSoup(driver.page_source, 'lxml')
print(html_data)

    

# if __name__ == '__main__':
# 	get_amazomoton_product("phone")
# Out:
# <!DOCTYPE html>
# <html class="a-js a-canvas a-svg a-offline a-drag-drop a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-touch a-gradients a-transform3d a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition a-ember" data-19ax5a9jf="dingo" data-aui-build-date="3.19.7-2019-11-04" lang="en-us"><!-- sp:feature:head-start --><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/><link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/><link href="https://m.media-amazon.com" rel="dns-prefetch"/><link href="https://completion.amazon.com" rel="dns-prefetch"/><!-- sp:feature:aui-assets -->
# ...

# %%
product_url = []
product_price = []

# %%
product_url_tag = html_data.find_all('a', class_="a-size-base a-link-normal s-no-hover a-text-normal")

price_and_link_dict = {}

for each in product_url_tag:
    if each.span(class_= "a-offscreen"):
#         print(type(each.span(class_="a-offscreen")[0].text))
#         print(type(each['href']))
        price_and_link_dict.update({each['href'] : each.span(class_="a-offscreen")[0].text})

for one in price_and_link_dict:
#     print(price_and_link_dict[one].replace('$', ''))
#     print(one)
    var = price_and_link_dict[one].replace('$', '')
    float_num = float(var)
    price_and_link_dict[one].update({one : float_num})
#     print(float_num)
#     print(int(price_and_link_dict[one].replace('$', '')))

for i in sorted (price_and_link_dict):
    print ((i, price_and_link_dict[i])) 

# print(price_and_link_dict)
# print(product_url_tag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-17978033d70d> in <module>
#      14     var = price_and_link_dict[one].replace('$', '')
#      15     float_num = float(var)
# ---> 16     price_and_link_dict[one].update({one : float_num})
#      17 #     print(float_num)
#      18 #     print(int(price_and_link_dict[one].replace('$', '')))
#
# AttributeError: 'str' object has no attribute 'update'
